# %%
pip install nanonispy2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nanonispy2 as nap
import matplotlib.pyplot as plt

# %%
filename = "/Users/aryanpatel/Desktop/ADS2002/Ag111_APT_007.sxm" # Filename of the sxm file containing raw STM data
sxm = nap.read.Scan(filename) # Read in the sxm file
im = sxm.signals["Z"]["backward"] # Full out the image in the 'forward' direction


plt.imshow(im)
